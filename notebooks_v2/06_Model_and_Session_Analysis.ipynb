# %% [markdown]
# # 06 — Analysis v2

# %%
import sys
from pathlib import Path
NB = Path.cwd() if Path.cwd().name == 'notebooks_v2' else Path.cwd() / 'notebooks_v2'
sys.path.insert(0, str(NB))
from lib.paths import ensure_notebook_paths
ensure_notebook_paths()
from lib.paths import CHECKPOINTS_DIR
from lib.har_analysis import run_full_analysis
ckpt = CHECKPOINTS_DIR / 'har_vjepa_v2_12c_100each.pt'
run_full_analysis(ckpt, split='subject') if ckpt.is_file() else print('Train first')
# Out:
# Train first

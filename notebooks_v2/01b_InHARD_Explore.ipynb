# %% [markdown]
# # 01b — InHARD EDA (v2)

# %%
import sys
from pathlib import Path
NB = Path.cwd() if Path.cwd().name == 'notebooks_v2' else Path.cwd() / 'notebooks_v2'
sys.path.insert(0, str(NB))
from lib.paths import ensure_notebook_paths
ensure_notebook_paths()
from lib.inhard_eda import load_segmented_eda, disk_vs_csv_summary, save_eda_summary, INHARD_EDA_DIR
from lib.paths import find_inhard_root
ROOT = find_inhard_root()
df = load_segmented_eda(ROOT)
print(disk_vs_csv_summary(ROOT))
save_eda_summary(df, ROOT)
print('Saved →', INHARD_EDA_DIR)

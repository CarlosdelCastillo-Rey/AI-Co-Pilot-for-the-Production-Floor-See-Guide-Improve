# %% [markdown]
# # 08 — (deprecated) use notebook 00
#
# V-JEPA + DINOv2 comparison is now built into **`00_Pipeline_Run_All.ipynb`**:
#
# ```python
# CFG = PipelineConfig(
#     backbones=("vjepa", "dinov2"),
#     run_analysis=True,
#     run_compare=True,
# )
# run_pipeline(CFG)
# ```
#
# Open **00** and run all cells.
